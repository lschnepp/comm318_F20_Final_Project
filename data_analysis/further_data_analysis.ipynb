# %% [markdown]
# # Data Analysis

# %% [markdown]
# * This notebook analyzes the data in the data frame drug-use-by-age.csv.

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
du_df = pd.read_csv('../data/drug-use-by-age.csv')

# %%
du_df
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0      12  2798          3.9                3.0            1.1
# 1      13  2757          8.5                6.0            3.4
# 2      14  2792         18.1                5.0            8.7
# 3      15  2956         29.2                6.0           14.5
# 4      16  3058         40.1               10.0           22.5
# 5      17  3038         49.3               13.0           28.0
# 6      18  2469         58.7               24.0           33.7
# 7      19  2223         64.6               36.0           33.4
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# ...

# %%
du_df.columns
# Out:
# Index(['age', 'n', 'alcohol-use', 'alcohol-frequency', 'marijuana-use',
#        'marijuana-frequency', 'cocaine-use', 'cocaine-frequency', 'crack-use',
#        'crack-frequency', 'heroin-use', 'heroin-frequency', 'hallucinogen-use',
#        'hallucinogen-frequency', 'inhalant-use', 'inhalant-frequency',
#        'pain-releiver-use', 'pain-releiver-frequency', 'oxycontin-use',
#        'oxycontin-frequency', 'tranquilizer-use', 'tranquilizer-frequency',
#        'stimulant-use', 'stimulant-frequency', 'meth-use', 'meth-frequency',
#        'sedative-use', 'sedative-frequency'],
#       dtype='object')

# %%
du_df.shape
# Out:
# (17, 28)

# %%
#renaming the columns to fit my preferences and for ease when coding: 
duname_dict = {
    "alcohol-use": "alcohol_use", 
    "alcohol-frequency": "alcohol_frequency", 
    "marijuana-use": "marijuana_use", 
    "marijuana-frequency": "marijuana_frequency", 
    "cocaine-use": "cocaine_use", 
    "cocaine-frequency": "cocaine_frequency", 
    "crack-use": "crack_use", 
    "crack-frequency": "crack_frequency",
    "oxycontin-use": "oxycontin_use", 
    "oxycontin-frequency": "oxycontin_frequency", 
    "tranquilizer-use": "tranquilizer_use", 
    "tranquilizer-frequency": "tranquilizer_frequency", 
    "stimulant-use": "stimulant_use", 
    "stimulant-frequency": "stimulant_frequency", 
    "meth-use": "meth_use", 
    "meth-frequency": "meth_frequency", 
    "sedative-use": "sedative_use", 
    "sedative-frequency": "sedative_frequency" 
}

# %%
du_df = du_df.rename(columns=duname_dict)

# %%
du_df
# Out:
#       age     n  alcohol_use  alcohol_frequency  marijuana_use  \
# 0      12  2798          3.9                3.0            1.1
# 1      13  2757          8.5                6.0            3.4
# 2      14  2792         18.1                5.0            8.7
# 3      15  2956         29.2                6.0           14.5
# 4      16  3058         40.1               10.0           22.5
# 5      17  3038         49.3               13.0           28.0
# 6      18  2469         58.7               24.0           33.7
# 7      19  2223         64.6               36.0           33.4
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# ...

# %% [markdown]
# * Use is the Percentage of those in an age group who used x drug in the past 12 months
# * Frequency is the Median number of times a user in an age group used x drug in the past 12 months

# %%
colstouse = ["alcohol_use", "alcohol_frequency", "marijuana_use",  "marijuana_frequency", "cocaine_use", 
    "cocaine_frequency"]
print(colstouse)
# Out:
# ['alcohol_use', 'alcohol_frequency', 'marijuana_use', 'marijuana_frequency', 'cocaine_use', 'cocaine_frequency']

# %%
du_df[["age", "n", "alcohol_use", "alcohol_frequency", "marijuana_use",  "marijuana_frequency", "cocaine_use", 
    "cocaine_frequency"]]
# Out:
#       age     n  alcohol_use  alcohol_frequency  marijuana_use  \
# 0      12  2798          3.9                3.0            1.1
# 1      13  2757          8.5                6.0            3.4
# 2      14  2792         18.1                5.0            8.7
# 3      15  2956         29.2                6.0           14.5
# 4      16  3058         40.1               10.0           22.5
# 5      17  3038         49.3               13.0           28.0
# 6      18  2469         58.7               24.0           33.7
# 7      19  2223         64.6               36.0           33.4
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# ...

# %%
colstouse = ["alcohol_use", "alcohol_frequency",  "cocaine_use", "cocaine_frequency"]
print(colstouse)
# Out:
# ['alcohol_use', 'alcohol_frequency', 'cocaine_use', 'cocaine_frequency']

# %% [markdown]
# ## Observations:
# * Alcohol use increases as one gets older, and begins to decline at the 30-34 age group.
# * Marijuana use increases as one gets older, and begins to decline at the 20-21 age group.
# * Cocaine use increases as one gets older, and begins to decline at the 20-21 age group.

# %%
du_df [["age", "n", "crack_use", "crack_frequency","oxycontin_use", "oxycontin_frequency", "stimulant_use", "stimulant_frequency", "meth_use", 
"meth_frequency","sedative_use", "sedative_frequency"]]
# Out:
#       age     n  crack_use crack_frequency  oxycontin_use oxycontin_frequency  \
# 0      12  2798        0.0               -            0.1                24.5
# 1      13  2757        0.0             3.0            0.1                41.0
# 2      14  2792        0.0               -            0.4                 4.5
# 3      15  2956        0.1             9.5            0.8                 3.0
# 4      16  3058        0.0             1.0            1.1                 4.0
# 5      17  3038        0.1            21.0            1.4                 6.0
# 6      18  2469        0.4            10.0            1.7                 7.0
# 7      19  2223        0.5             2.0            1.5                 7.5
# 8      20  2271        0.6             5.0            1.7                12.0
# 9      21  2354        0.5            17.0            1.3                13.5
# 10  22-23  4707        0.5             5.0            1.7                17.5
# ...

# %% [markdown]
# * Split the data frame into less hard and harder drugs

# %%
total_df=du_df[['age','alcohol_use']]

total_df.plot(x='age', y='alcohol_use', kind='bar', figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='age'>

# %%
total_df=du_df[['age','marijuana_use']]

total_df.plot(x='age', y='marijuana_use', kind='bar', figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='age'>

# %%
total_df=du_df[['age','cocaine_use']]

total_df.plot(x='age', y='cocaine_use', kind='bar', figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# I am looking at how different age ranges engage with alcohol and cocaine.
# * four different age ranges: 12-17, 18-25, 25-64, and 65+ and look at their consumption of specific drugs.

# %% [markdown]
# Note: I am looking at alcohol and cocaine use because I found in my initial_data_analysis notebook that these two drugs are the most lethal that are in this dataset and will support my data story

# %%
du_df.iloc[0:6][['age', 'alcohol_use', 'cocaine_use']]
# Out:
#   age  alcohol_use  cocaine_use
# 0  12          3.9          0.1
# 1  13          8.5          0.1
# 2  14         18.1          0.1
# 3  15         29.2          0.5
# 4  16         40.1          1.0
# 5  17         49.3          2.0

# %%
du_df.iloc[6:12][['age', 'alcohol_use', 'cocaine_use']]
# Out:
#       age  alcohol_use  cocaine_use
# 6      18         58.7          3.2
# 7      19         64.6          4.1
# 8      20         69.7          4.9
# 9      21         83.2          4.8
# 10  22-23         84.2          4.5
# 11  24-25         83.1          4.0

# %%
du_df.iloc[12:16][['age', 'alcohol_use', 'cocaine_use']]
# Out:
#       age  alcohol_use  cocaine_use
# 12  26-29         80.7          3.2
# 13  30-34         77.5          2.1
# 14  35-49         75.0          1.5
# 15  50-64         67.2          0.9

# %%
du_df.iloc[15:17][['age', 'alcohol_use', 'cocaine_use']]
# Out:
#       age  alcohol_use  cocaine_use
# 15  50-64         67.2          0.9
# 16    65+         49.3          0.0
